# %%
from time import *
import random as r

def mistake (partest, usertest):
    error = 0
    for i in range(len(partest)):
        try:
            if partest [i] != usertest[i]:
                error+=1
        except:
             error+=1       

    return error

def speed_time(time_s,time_e, userinput):
    time_delay= time_e - time_s
    time_r = round (time_delay,2)
    speed =len(userinput)/time_r
    return round(speed)

if __name__ == '__main__':


    while True:
        ck = input("Ready to test : yes / no : ")
        if ck == "yes":

            test = ["Time is gold and time is money, if we utilıze it in a prop way and would not tolerate to waste even a single minute, because lost minutes add up to lost hours, lost hours add up to lost days, 1Ost days add up to lost years and lost",
" Check your WPM typing speed with this free software! Regular practice of online typing test in English paragraph for 10 minutes will enhance your typing skill. To change a paragraph of typing test click on the next test button. If the new paragraph does not load properly then click on the next button again.",
" Regular practice of online typing test in English paragraph for 10 minutes will enhance your typing skill. To change a paragraph of typing test click on the next test button. If the new paragraph does not load properly then click on the next button again."]
            test1 = r.choice(test)

            print("  ***** Typing Speed*****   ")
            print(test1)
            print()
            print()
            time_1 = time()
            testinput = input("Enter : ")
            time_2= time()

            print("Speed: ",speed_time(time_1,time_2,testinput),"w/sec")
            print("Error : ", mistake(test1,testinput))
 
        elif ck=="no":
            print("thank you ")
            break
        else:
            print(" wrong input")
from time import *
import random as r

def mistake (partest, usertest):
    error = 0
    for i in range(len(partest)):
        try:
            if partest [i] != usertest[i]:
                error+=1
        except:
             error+=1       

    return error

def speed_time(time_s,time_e, userinput):
    time_delay= time_e - time_s
    time_r = round (time_delay,2)
    speed =len(userinput)/time_r
    return round(speed)

if __name__ == '__main__':


    while True:
        ck = input("Ready to test : yes / no : ")
        if ck == "yes":

            test = ["Time is gold and time is money, if we utilıze it in a prop way and would not tolerate to waste even a single minute, because lost minutes add up to lost hours, lost hours add up to lost days, 1Ost days add up to lost years and lost",
" Check your WPM typing speed with this free software! Regular practice of online typing test in English paragraph for 10 minutes will enhance your typing skill. To change a paragraph of typing test click on the next test button. If the new paragraph does not load properly then click on the next button again.",
" Regular practice of online typing test in English paragraph for 10 minutes will enhance your typing skill. To change a paragraph of typing test click on the next test button. If the new paragraph does not load properly then click on the next button again."]
            test1 = r.choice(test)

            print("  ***** Typing Speed*****   ")
            print(test1)
            print()
            print()
            time_1 = time()
            testinput = input("Enter : ")
            time_2= time()

            print("Speed: ",speed_time(time_1,time_2,testinput),"w/sec")
            print("Error : ", mistake(test1,testinput))
 
        elif ck=="no":
            print("thank you ")
            break
        else:
            print(" wrong input")
# Out:
# Ready to test : yes / no : yes
#   ***** Typing Speed*****
# Time is gold and time is money, if we utilıze it in a prop way and would not tolerate to waste even a single minute, because lost minutes add up to lost hours, lost hours add up to lost days, 1Ost days add up to lost years and lost
